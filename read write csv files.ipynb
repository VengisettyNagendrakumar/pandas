# %%
import pandas as pd
df=pd.read_csv("weather.csv")
df
# Out:
#           day  temp  windspeed  event
# 0  01-01-2017    32          6   rain
# 1  01-02-2017    34          1  sunny
# 2  01-03-2017    23          2   snow
# 3  01-04-2017    56          7  snow
# 4  01-05-2017    78          4   rain
# 5  01-06-2017    98          2  sunny

# %%
df=pd.read_csv("weather.csv",header=1)
df
# Out:
#    01-01-2017  32  6   rain
# 0  01-02-2017  34  1  sunny
# 1  01-03-2017  23  2   snow
# 2  01-04-2017  56  7  snow
# 3  01-05-2017  78  4   rain
# 4  01-06-2017  98  2  sunny

# %%
df=pd.read_csv("weather.csv",header=None)
df
# Out:
#             0     1          2      3
# 0         day  temp  windspeed  event
# 1  01-01-2017    32          6   rain
# 2  01-02-2017    34          1  sunny
# 3  01-03-2017    23          2   snow
# 4  01-04-2017    56          7  snow
# 5  01-05-2017    78          4   rain
# 6  01-06-2017    98          2  sunny

# %%
df
# Out:
#             0     1          2      3
# 0         day  temp  windspeed  event
# 1  01-01-2017    32          6   rain
# 2  01-02-2017    34          1  sunny
# 3  01-03-2017    23          2   snow
# 4  01-04-2017    56          7  snow
# 5  01-05-2017    78          4   rain
# 6  01-06-2017    98          2  sunny

# %%
df=pd.read_csv("weather.csv",header=None,names=['Day','Temp','Windspeed','Event'])
df
# Out:
#           Day  Temp  Windspeed  Event
# 0         day  temp  windspeed  event
# 1  01-01-2017    32          6   rain
# 2  01-02-2017    34          1  sunny
# 3  01-03-2017    23          2   snow
# 4  01-04-2017    56          7  snow
# 5  01-05-2017    78          4   rain
# 6  01-06-2017    98          2  sunny

# %%
df=pd.read_csv("weather.csv",header=0)
df
# Out:
#           day  temp  windspeed  event
# 0  01-01-2017    32          6   rain
# 1  01-02-2017    34          1  sunny
# 2  01-03-2017    23          2   snow
# 3  01-04-2017    56          7  snow
# 4  01-05-2017    78          4   rain
# 5  01-06-2017    98          2  sunny

# %%
df=pd.read_csv("weather.csv",nrows=3)
df
# Out:
#           day  temp  windspeed  event
# 0  01-01-2017    32          6   rain
# 1  01-02-2017    34          1  sunny
# 2  01-03-2017    23          2   snow

# %%
df=pd.read_csv("weather.csv",na_values=['notavailable','n.a.'])
df
# Out:
#           day  temp  windspeed  event
# 0  01-01-2017    32          6   rain
# 1  01-02-2017    34          1  sunny
# 2  01-03-2017    23          2   snow
# 3  01-04-2017    56          7  snow
# 4  01-05-2017    78          4   rain
# 5  01-06-2017    98          2  sunny

# %%
df.to_csv('new.csv')
df
# Out:
#           day  temp  windspeed  event
# 0  01-01-2017    32          6   rain
# 1  01-02-2017    34          1  sunny
# 2  01-03-2017    23          2   snow
# 3  01-04-2017    56          7  snow
# 4  01-05-2017    78          4   rain
# 5  01-06-2017    98          2  sunny

# %%
p=df.to_csv('new.csv',index=False)
p
